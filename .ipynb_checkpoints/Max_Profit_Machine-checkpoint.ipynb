# %%
#Imports

# 1. open individual file
# 2. iterate over days and update min close price, max close price, max and max difference
# 3. for each new day that has a lower min start calculating the max difference again
# 4. if max difference is ever larger than the previous, save that instead
# 5. Now you have this for one stock, do it for all the stocks!!!!

import pandas as pd
import numpy as np
import cufflinks as cf
import time
import json
import random
import requests
import os
from datetime import datetime
import time
import matplotlib.pyplot as plt
from matplotlib.dates import date2num

import plotly
import  plotly.plotly as py
import plotly.graph_objs as go

#read in the first file
#input_folder = os.path.join("..","Data","Test_stock")
input_folder = os.path.join("SP 100")
output_file = os.path.join("Combined Stock Data.csv")

plotly.tools.set_credentials_file(username='klinga88', api_key='r4j4H1eCCeIYTpmYRxx5')
plotly.tools.set_config_file(world_readable=True)

# %%
#function: Determines the largest difference between close prices given a stock's daily historical dataframe
#input: historical daily stock data in the form of a pandas dataframe
#output: Largest difference between two close prices, minimum close date, minimum close price,maximum close date,
#        maximum close price

def maxChange(data_df):
    min_close = data_df.iloc[0,4] #initiliaze first close price in the list
    min_date = data_df.iloc[0,0] #initiliaze first close price in the list
    max_close = None
    max_date = None
    biggest_diff = data_df.iloc[1,4] - data_df.iloc[0,4] # initialize to the price difference from first day to second in list

    for index, row in data_df.iterrows():
        if (row["Close"] <= min_close):  
            min_close = row["Close"]
            min_date = row["Date"]
        elif (row["Close"] - min_close) > biggest_diff:
            biggest_diff = row["Close"] - min_close
            max_close = row["Close"]
            max_date = row["Date"]

    #print(f"Biggest Change: {biggest_diff}, from:{min_date} to {max_date}")
    
    return biggest_diff, min_date, min_close, max_date, max_close

# %%
#Finds maximum profit from arbitrary start date to arbitrary end date
def maxChange_1(data_df):
    min_close_row = data_df.iloc[0,:]
    #get index of max element in close column of data frame
    max_close_index = data_df['Close'].idxmax()
    max_close_row =  data_df.loc[data_df['Close'].idxmax()]
    
    for index, row in data_df.iterrows():
        if index >= max_close_index:
            break
        elif row['Close'] < min_close_row["Close"]:
            min_close_row = row
            
    return min_close_row,max_close_row

# %%
#Read in all historical stock price files
ticker_list = []
min_date_list = []
min_close_list = []
max_date = []
max_close = []


#read in all data in files and find maximum change between two dates, save to dataframe
counter=0
for filename in os.listdir(input_folder):
    
    ticker = filename.split(".")[0]
    input_file = os.path.join(input_folder,filename)
    
    try:
        data_df = pd.read_csv(input_file)
    except Exception as e: 
        print(e) 
        
    min_close_row,max_close_row = maxChange_1(data_df)
    ticker_list.append(ticker)
    min_date_list.append(min_close_row["Date"])
    min_close_list.append(min_close_row["Close"])
      
    counter +=1
if counter == 100:
    print(f'counter = {counter}, retrieved all files!')
else:
    print(f'counter = {counter}, did not retrieve all files!')
# Out:
# counter = 100, retrieved all files!

# %%
combined_ticker = []
combined_biggest_diff = []
combined_min_date = []
combined_min_close = []
combined_max_date = []
combined_max_close = []
combined_time_in_market = []
counter = 0
#Iterate over each stock in the input folder
for filename in os.listdir(input_folder):
    ticker = filename.split(".")[0]
    input_file = os.path.join(input_folder,filename)
    
    try:
        data_df = pd.read_csv(input_file)
    except Exception as e: 
        print(e) 
        
    min_close_row,max_close_row = maxChange_1(data_df)
    combined_ticker.append(ticker)
    combined_min_date.append(min_close_row["Date"])
    combined_min_close.append(min_close_row["Close"])
    combined_max_date.append(max_close_row["Date"])
    combined_max_close.append(max_close_row["Close"])
    combined_biggest_diff.append(max_close_row["Close"]-min_close_row["Close"]) 
    max_close_date = datetime.strptime(max_close_row["Date"], "%Y-%m-%d")
    min_close_date = datetime.strptime(min_close_row["Date"], "%Y-%m-%d")
    combined_time_in_market.append((max_close_date-min_close_date).days)
    counter +=1
    #print(f'counter: {counter}')
combined_df = pd.DataFrame({"Ticker":combined_ticker,
                           "Biggest Difference":combined_biggest_diff,
                           "Minimum Close Date":combined_min_date,
                           "Minimum Close":combined_min_close,
                           "Maximum Close Date":combined_max_date,
                           "Maximum Close":combined_max_close,
                           "Time in Market":combined_time_in_market})

# %%
#Add in sector information for each stock
combined_df["Ticker"] = combined_df["Ticker"].str.upper()
stock_sectors = pd.read_csv("SP_100_Sectors.csv")
combined_df = combined_df.merge(stock_sectors,how="left",on="Ticker")
combined_df
# Out:
#    Ticker  Biggest Difference Minimum Close Date  Minimum Close  \
# 0    AAPL           175.37949         1985-08-15        0.23051
# 1    ABBV            68.23800         2013-01-08       28.24200
# 2     ABT            55.66010         1984-03-26        0.65990
# 3     ACN           126.65400         2005-04-27       18.23600
# 4     AGN           330.41440         1993-02-22        6.06560
# 5     AIG          1887.93400         1984-12-03       46.12600
# 6     ALL            90.25900         1994-04-21        8.92100
# 7    AMGN           190.92985         1984-11-16        0.07015
# 8    AMZN          1131.48000         1997-05-22        1.40000
# 9     AXP            95.94019         1974-10-03        0.48981
# 10     BA           264.39805         1974-01-08        0.31195
# 11    BAC            49.44740         1987-12-03        2.30960
# 12   BIIB           438.10761         1994-12-16        0.32239
# 13     BK            53.55560         1990-10-30        1.07140
# ...

# %%
trace0=go.Scatter(
        x=combined_df["Time in Market"]/365,
        y=combined_df["Biggest Difference"],
        mode='markers',
        marker=dict(size=14,
                    line=dict(width=1),
                    color='rgb(55, 83, 109)',
                    opacity=0.3
                   ),
        
        text= combined_df["Company"]) # The hover text goes here... 
;

layout= go.Layout(
    title= 'Years to Hold for Maximum Profit vs Maximum Profit',
    hovermode= 'closest',
    xaxis= dict(
        title= 'Years to Hold for Maximum Profit',
        ticklen= 5,
        zeroline= False,
        gridwidth= 2,
    ),
    yaxis=dict(
        title='Maximum Profit',
        ticklen=5,
        gridwidth=2,
    ),
    showlegend=False
)
fig = go.Figure(data=[trace0], layout=layout)
py.iplot(fig, filename='scatter_hover_labels')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~klinga88/11.embed" height="525px" width="100%"></iframe>

# %%
combined_df["Minimum Close Date"] =  pd.to_datetime(combined_df["Minimum Close Date"])
combined_df["Maximum Close Date"] =  pd.to_datetime(combined_df["Maximum Close Date"])

combined_df.to_csv(output_file)

# %%
#we will need these dataframes later
datelist_df = pd.DataFrame()
min_close_dates_df = pd.DataFrame()
max_close_dates_df = pd.DataFrame()

#create range of dates for min and max dates from dataset
datelist_df["Date"] = pd.date_range(start=combined_df["Minimum Close Date"].min(), end=combined_df["Maximum Close Date"].max())
datelist_df["Year"] =pd.DatetimeIndex(datelist_df["Date"]).year 
datelist_df["Month"] = pd.DatetimeIndex(datelist_df["Date"]).month
datelist_df = datelist_df[["Year","Month"]] #remove original date
datelist_df = datelist_df["Year"].map(str)+"-"+datelist_df["Month"].map(str)
datelist_df = datelist_df.drop_duplicates()
datelist_df = pd.DataFrame(datelist_df)
datelist_df["Year-Month"] = datelist_df
datelist_df = datelist_df.reset_index()
datelist_df = datelist_df[["Year-Month"]]

#strip day from date to leave just year and month
min_close_dates_df["Year"] = pd.DatetimeIndex(combined_df["Minimum Close Date"]).year
min_close_dates_df["Month"] = pd.DatetimeIndex(combined_df["Minimum Close Date"]).month
max_close_dates_df["Year"] = pd.DatetimeIndex(combined_df["Maximum Close Date"]).year
max_close_dates_df["Month"] = pd.DatetimeIndex(combined_df["Maximum Close Date"]).month

#Turn year-month into a single column for min and max counts
min_close_dates_df["Year-Month"] = min_close_dates_df["Year"].map(str)+"-"+min_close_dates_df["Month"].map(str)
max_close_dates_df["Year-Month"] = max_close_dates_df["Year"].map(str)+"-"+max_close_dates_df["Month"].map(str)

min_close_dates_df = min_close_dates_df.reset_index()
max_close_dates_df = max_close_dates_df.reset_index()

min_close_dates_df = min_close_dates_df.groupby(["Year-Month"],as_index=False).count()
min_close_dates_df = min_close_dates_df.rename(columns={"index":"Count"})
min_close_dates_df = min_close_dates_df[["Year-Month","Count"]]
max_close_dates_df = max_close_dates_df.groupby(["Year-Month"],as_index=False).count()
max_close_dates_df = max_close_dates_df.rename(columns={"index":"Count"})
max_close_dates_df = max_close_dates_df[["Year-Month","Count"]]

#create the dataframe containing number of min days and max days for all days in time period.  We will trim date range after
min_max_df = datelist_df.merge(min_close_dates_df,how="left",on="Year-Month")
min_max_df = min_max_df.merge(max_close_dates_df,how="left",on="Year-Month")
min_max_df = min_max_df.fillna(value=0)

min_max_df
# Out:
#     Year-Month  Count_x  Count_y
# 0       1962-6      2.0      0.0
# 1       1962-7      0.0      0.0
# 2       1962-8      0.0      0.0
# 3       1962-9      0.0      0.0
# 4      1962-10      0.0      0.0
# 5      1962-11      0.0      0.0
# 6      1962-12      0.0      0.0
# 7       1963-1      0.0      0.0
# 8       1963-2      0.0      0.0
# 9       1963-3      0.0      0.0
# 10      1963-4      0.0      0.0
# 11      1963-5      0.0      0.0
# 12      1963-6      0.0      0.0
# 13      1963-7      0.0      0.0
# 14      1963-8      0.0      0.0
# 15      1963-9      0.0      0.0
# 16     1963-10      0.0      0.0
# 17     1963-11      0.0      0.0
# 18     1963-12      0.0      0.0
# 19      1964-1      0.0      0.0
# 20      1964-2      0.0      0.0
# 21      1964-3      0.0      0.0
# 22      1964-4      0.0      0.0
# 23      1964-5      0.0      0.0
# 24      1964-6      0.0      0.0
# 25      1964-7      0.0      0.0
# 26      1964-8      0.0      0.0
# ...

# %%
x0 = min_max_df["Count_x"]
x1 = min_max_df["Count_y"]
y= min_max_df["Year-Month"]


trace1 = go.Bar(
    x=y,
    y=x0,
    name="Min Close Price Date",
    marker=dict(
        color='rgb(55, 83, 109)'
    )
)
trace2 = go.Bar(
    x=y,
    y=x1,
    name='Max Close Price Date',
    marker=dict(
        color='rgb(26, 118, 255)'
    )
)
data = [trace1, trace2]
layout = go.Layout(
    title='Comparison of Minimum Close Price Date and Maximum Close Price Date for S&P 100 Stocks',
    xaxis=dict(
        title='Date (Year-Month)',
        tickfont=dict(
            size=14,
            color='rgb(107, 107, 107)'
        )
    ),
    yaxis=dict(
        title='Count',
        titlefont=dict(
            size=16,
            color='rgb(107, 107, 107)'
        ),
        tickfont=dict(
            size=14,
            color='rgb(107, 107, 107)'
        )
    ),
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15,
    bargroupgap=0.1
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='style-bar')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~klinga88/9.embed" height="525px" width="100%"></iframe>
