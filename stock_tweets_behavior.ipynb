# %%
# Dependencies
import tweepy
import json
import numpy as np
from config import consumer_key, consumer_secret, access_token, access_token_secret
from datetime import datetime
import pandas as pd
from nltk.tokenize import word_tokenize
import re
import matplotlib.pyplot as plt
import time

import plotly
plotly.tools.set_credentials_file(username='joelboyette', api_key='MBF4ThuV6dcFCF3unLzM')

import plotly.plotly as py
import plotly.graph_objs as go

# %%
# Twitter API Keys
consumer_key = consumer_key
consumer_secret = consumer_secret
access_token = access_token
access_token_secret = access_token_secret

# %%
# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser(), wait_on_rate_limit=True)

# %%
#list to hold tweet data
tweet_text = []
tweet_times = []
unique_ids = []
tweet_user = []
tweet_handle = []
tweet_followers = []

tweet_search_keyword = []
tweet_post_retweets = []
tweet_likes = []
bad_handle = []

oldest_tweet = None
sinceId = None
tweet_count = 0

# %%
top_stocks = pd.read_csv("SP_100_Tickers_final.csv", encoding ='latin')

#clean out bad characters
top_stocks["Twitter_handle"] =  top_stocks.Twitter_handle.str.replace('\xa0','')

top_stocks_handle = top_stocks["Twitter_handle"].tolist()

stock_keywords = top_stocks_handle

# %%
#loop through keywords
for keyword in stock_keywords:

    oldest_tweet = None
    
    #time.sleep(5)
    
    try:
        for x in range(1,12):
            #put tweeter searches in list
            public_tweets = api.user_timeline(keyword, count = 200, max_id = oldest_tweet)

            # Loop through all tweets
            for tweet in public_tweets:

                tweet_id = tweet["id"]

                 # if Id is unique tweet data will be added
                if tweet_id not in unique_ids:
                    
                    unique_ids.append(tweet_id)
                    tweet_search_keyword.append(keyword)
                    
                    fix_string = tweet["text"].rstrip('\r\n')
                    tweet_text.append(fix_string)
                    
                    tweet_user.append(tweet["user"]["name"])
                    
                    tweet_followers.append(tweet["user"]["followers_count"])
                    
                    tweet_times.append(tweet["created_at"])
                    
                    tweet_post_retweets.append(tweet["retweet_count"])
                    tweet_likes.append(tweet["favorite_count"])
                        
                    oldest_tweet = tweet_id - 1
                    tweet_count += 1

        
        print(keyword + " grabbed num tweets: " + str(tweet_count))
    
    except:
        bad_handle.append(keyword)
        print(f'{keyword} doesnt have twitter')
# Out:
# @Apple grabbed num tweets: 0
# @abbvie grabbed num tweets: 2200
# @AbbottGlobal grabbed num tweets: 4398
# @Accenture grabbed num tweets: 6596
# @Allergan grabbed num tweets: 6911
# @AIGinsurance grabbed num tweets: 9111
# @Allstate grabbed num tweets: 11310
# @Amgen grabbed num tweets: 13510
# @amazon grabbed num tweets: 15704
# @AmericanExpress grabbed num tweets: 17904
# @boeing grabbed num tweets: 20099
# @BankofAmerica grabbed num tweets: 22293
# @biogen grabbed num tweets: 24493
# @BNYMellon grabbed num tweets: 26693
# @BookingHoldings grabbed num tweets: 28143
# @blackrock grabbed num tweets: 30343
# @bmsnews grabbed num tweets: 32543
# @BHHSRealEstate grabbed num tweets: 34699
# @Citi grabbed num tweets: 36898
# @CaterpillarInc grabbed num tweets: 39098
# @Celgene grabbed num tweets: 41298
# @CharterCom grabbed num tweets: 41308
# @CP_News grabbed num tweets: 42884
# @comcast grabbed num tweets: 45084
# @CapitalOne grabbed num tweets: 47282
# @conocophillips grabbed num tweets: 49478
# @Costco doesnt have twitter
# @Cisco grabbed num tweets: 51676
# @CVSHealth grabbed num tweets: 53876
# @Chevron grabbed num tweets: 56073
# @Danaher Corporation       grabbed num tweets: 56483
# @WaltDisneyCo grabbed num tweets: 58367
# @DukeEnergy grabbed num tweets: 60567
# @DowDuPontCo grabbed num tweets: 60602
# @Emerson Electric Co.      grabbed num tweets: 60602
# @Exelon grabbed num tweets: 62798
# @Ford grabbed num tweets: 64998
# @facebook grabbed num tweets: 67198
# @FedEx grabbed num tweets: 69398
# @20thcenturyfox grabbed num tweets: 71593
# @GDMS grabbed num tweets: 73789
# @generalelectric grabbed num tweets: 75982
# @GileadSciences grabbed num tweets: 78180
# @GM grabbed num tweets: 80380
# @Google grabbed num tweets: 82580
# @GoldmanSachs grabbed num tweets: 84780
# @Halliburton grabbed num tweets: 86715
# @HomeDepot grabbed num tweets: 88915
# @honeywell grabbed num tweets: 91114
# @IBM grabbed num tweets: 93314
# @intel grabbed num tweets: 95513
# @JNJNews grabbed num tweets: 97713
# @jpmorgan grabbed num tweets: 99912
# @KraftHeinzCo grabbed num tweets: 101173
# @Kinder_Morgan grabbed num tweets: 102723
# @CocaCola grabbed num tweets: 104923
# @LillyPad grabbed num tweets: 107120
# @LockheedMartin grabbed num tweets: 109320
# @Lowes grabbed num tweets: 111520
# @Mastercard grabbed num tweets: 113720
# @McDonaldsCorp grabbed num tweets: 115920
# @MDLZ grabbed num tweets: 118120
# @Medtronic grabbed num tweets: 120319
# @MetLife grabbed num tweets: 122519
# @3M grabbed num tweets: 124719
# @AltriaNews grabbed num tweets: 126540
# @Merck grabbed num tweets: 128740
# @MorganStanley grabbed num tweets: 130940
# @Microsoft grabbed num tweets: 133138
# @NextEraEnergyR grabbed num tweets: 134290
# @netflix grabbed num tweets: 136484
# @Nike grabbed num tweets: 138684
# @nvidia grabbed num tweets: 140884
# @Oracle grabbed num tweets: 143084
# @OXY_Petroleum grabbed num tweets: 143272
# @PepsiCo grabbed num tweets: 145472
# @pfizer grabbed num tweets: 147672
# @ProcterGamble grabbed num tweets: 149867
# @PMIScience grabbed num tweets: 150333
# @PayPal grabbed num tweets: 152533
# @Qualcomm grabbed num tweets: 154732
# @Raytheon grabbed num tweets: 156932
# @Starbucks grabbed num tweets: 159132
# @Schlumberger        doesnt have twitter
# @SouthernCoGas grabbed num tweets: 159503
# @Simon Property Group, Inc.     grabbed num tweets: 159503
# @ATT grabbed num tweets: 161703
# @Target grabbed num tweets: 163903
# @TXInstruments grabbed num tweets: 166103
# @UnitedHealthGrp grabbed num tweets: 167623
# @UnionPacific grabbed num tweets: 169823
# @UPS grabbed num tweets: 172023
# @US Bancorp       grabbed num tweets: 172023
# @UTC grabbed num tweets: 174222
# @VisaNews grabbed num tweets: 176419
# @verizon grabbed num tweets: 178619
# @Walgreens grabbed num tweets: 180819
# @WellsFargo grabbed num tweets: 183018
# @Walmart grabbed num tweets: 185218
# @exxonmobil grabbed num tweets: 187410

# %%
# Add each datetime object into the array
tweet_time_objects = []
for x in range(len(tweet_times)):
    tweet_datetime = datetime.strptime(tweet_times[x], "%a %b %d %H:%M:%S %z %Y")
    tweet_time_objects.append(tweet_datetime)

# %%
#check to make sure all list are the same length
print(len(tweet_search_keyword))
print(len(tweet_user))

print(len(tweet_followers))

print(len(unique_ids))
print("---------")
print(len(tweet_text))
print(len(tweet_time_objects))
print(bad_handle)
# Out:
# 187410
# 187410
# 187410
# 187410
# ---------
# 187410
# 187410
# ['@Costco', '@Schlumberger       ']

# %%
tweet_data.drop_duplicates(keep=False)

tweet_data.dropna(how="any")
# Out:
#         Followers                   Id        Name  \
# 0           49764  1012722879467835394      AbbVie
# 1           49764  1012312191851167744      AbbVie
# 2           49764  1011949798172299264      AbbVie
# 3           49764  1011696513259655169      AbbVie
# 4           49764  1011647806719881217      AbbVie
# 5           49764  1011584888863117312      AbbVie
# 6           49764  1011285411803648005      AbbVie
# 7           49764  1011207394788040704      AbbVie
# 8           49764  1010277077000642560      AbbVie
# 9           49764  1010213372611190785      AbbVie
# 10          49764  1010173005555781632      AbbVie
# 11          49764  1010166144894930947      AbbVie
# 12          49764  1009920035895291905      AbbVie
# 13          49764  1009863581100331009      AbbVie
# 14          49764  1009851169819291648      AbbVie
# 15          49764  1009767954643406848      AbbVie
# 16          49764  1009566156548689922      AbbVie
# 17          49764  1009566031285751808      AbbVie
# 18          49764  1009565900087885824      AbbVie
# 19          49764  1009428183777710081      AbbVie
# 20          49764  1009405553758670848      AbbVie
# 21          49764  1009199319847702538      AbbVie
# 22          49764  1009186589120106501      AbbVie
# 23          49764  1009118876930592769      AbbVie
# 24          49764  1009078169754796038      AbbVie
# 25          49764  1009073379134066689      AbbVie
# 26          49764  1008815550473166849      AbbVie
# 27          49764  1008799404931903488      AbbVie
# 28          49764  1008795914432106497      AbbVie
# 29          49764  1008756797082128384      AbbVie
# ...           ...                  ...         ...
# 187378     281662   669517668324610048  ExxonMobil
# 187379     281662   669290683505754112  ExxonMobil
# 187380     281662   669247896538234881  ExxonMobil
# 187381     281662   669206036620820481  ExxonMobil
# 187382     281662   669183219539968000  ExxonMobil
# 187383     281662   669182918430887937  ExxonMobil
# 187384     281662   668928547612966913  ExxonMobil
# 187385     281662   668891788711739392  ExxonMobil
# 187386     281662   668866597881290753  ExxonMobil
# 187387     281662   668844236599656448  ExxonMobil
# 187388     281662   668806000967884801  ExxonMobil
# 187389     281662   668576709839446016  ExxonMobil
# 187390     281662   668553807912148992  ExxonMobil
# 187391     281662   668533432809627648  ExxonMobil
# 187392     281662   668492402555011073  ExxonMobil
# 187393     281662   668447863278555136  ExxonMobil
# 187394     281662   668211311772323841  ExxonMobil
# 187395     281662   668172302501195777  ExxonMobil
# 187396     281662   668134807864516608  ExxonMobil
# 187397     281662   668103345991733248  ExxonMobil
# 187398     281662   668075418344423424  ExxonMobil
# 187399     281662   667864017512329217  ExxonMobil
# 187400     281662   667843885914324993  ExxonMobil
# 187401     281662   667834581786169344  ExxonMobil
# 187402     281662   667809669780340737  ExxonMobil
# 187403     281662   667801765291560960  ExxonMobil
# 187404     281662   667794611910348801  ExxonMobil
# 187405     281662   667776452826415106  ExxonMobil
# 187406     281662   667774427648626688  ExxonMobil
# 187407     281662   667750780451995648  ExxonMobil
#
#                                                      Text  Time Retweeted  \
# 0       We know more today about the biology and genet...               1
# 1       “You probably don’t think about it, but there’...               8
# 2       If you had a higher chance of developing #Alzh...               1
# 3       Learn more about the progress of our Calico pa...               7
# 4       We know patients have lots of questions before...               3
# 5       #Breaking: We are extending our collaboration ...              18
# 6       For us, diversity &amp; inclusion isn’t just f...               0
# 7       Just announced: a collaboration w/ Calibr and ...               9
# 8       That’s a wrap for Week of Possibilities 2018! ...               7
# 9       Thank you to our partners, employees &amp; loc...               9
# 10      See what we've been up to in Ireland during th...               0
# 11      RT @WrapUpLondon: What an outstanding group of...               5
# 12      RT @GlasswingRD: This Wednesday, June 20,  #Ab...               7
# 13      @Melinda_Blevins Thank you for your tweet. Whi...               0
# 14      We're rooting for team France! The garden is l...               2
# 15      Day 4 of our Week of Possibilities means we’re...               6
# 16      @GreenhillsColl @voluntireland @TheEchoOnline ...               0
# 17      RT @GreenhillsColl: Another extremely busy day...               2
# 18      RT @WrapUpLondon: The fantastic team of @abbvi...               5
# 19      Diversity and inclusion are the cornerstones o...               6
# 20      It’s hard to believe we’re halfway through our...               4
# 21      RT @VolunteerCanada: @abbviecanada   Faster th...               2
# 22      A rogue scientist. A mysterious gene. Plot of ...               4
# 23      What happens when two health economists stop b...               4
# 24      High five ✋to our colleagues in Germany! #AbbV...               2
# 25      What’s the power of 5? It's our 5th annual Wee...               7
# 26            @TimeHeroesOrg We're happy you're on board!               0
# 27      RT @voluntireland: And we’re on the move in Du...               4
# 28      Sweat equity takes on new meaning when it's 95...               0
# 29      It started as a commitment to 1 community. Now...               8
# ...                                                   ...             ...
# 187378  Explore our global stories to learn more about...               6
# 187379  #GetTheFacts in @WSJ from our Vice President o...               6
# 187380  #DYK a $100M commitment from ExxonMobil helped...               8
# 187381  ExxonMobil conducts cutting-edge R&amp;D throu...               4
# 187382  #GetTheFacts from @KenPCohen in the @WSJ: “Exx...               8
# 187383  RT @changeequation: #STEMworks is your go-to r...               9
# 187384  Find out more about the work we do each day to...              10
# 187385                   .@JADallas: It was our pleasure!               0
# 187386  Applying advanced #technology &amp; processes ...               5
# 187387  RT @changeequation: NEW STEMtistic: See why a ...              15
# 187388  RT @NASA: Katherine Johnson, to be awarded the...             847
# 187389  RT @saeverley: Even Democrats are now criticiz...              12
# 187390  Warm your home by keeping your curtains open d...               8
# 187391  ICYMI: Read @KenPCohen's @dallasnews op-ed: Co...               3
# 187392  Important read if you want to #GetTheFacts htt...               8
# 187393  Don't just believe critics claims, read the do...               7
# 187394  .@UTAustin to offer certificate in #engineerin...               8
# 187395  Former Democratic congressman pens @WSJ op-ed ...               6
# 187396  In its reporting on our #climate research, @LA...               7
# 187397  #Energy is the foundation for modern life &amp...              10
# 187398  #GetTheFacts via @WSJ about ExxonMobil's impac...               4
# 187399               .@DriveWestComm: Thanks for sharing!               0
# 187400          .@ASMEConferences: Thank you for sharing!               0
# 187401  Check out @KenPCohen's blog for the latest on ...               4
# 187402  #Weekend reading on ExxonMobil, #climate, #car...               6
# 187403  RT @Revkin: I'm no Exxon booster&gt; https://t...              13
# 187404  The spirit of innovation has delivered thousan...               6
# 187405  Today is the deadline to nominate an awesome t...               3
# 187406  RT @KenPCohen: Thanks to #fracking &amp; the i...              10
# 187407  ExxonMobil gives several presentations through...               5
#
#                       Time Stamp  Times liked Twitter_handle
# 0      2018-06-29 15:42:04+00:00            2        @abbvie
# 1      2018-06-28 12:30:09+00:00           23        @abbvie
# 2      2018-06-27 12:30:07+00:00           13        @abbvie
# 3      2018-06-26 19:43:39+00:00           14        @abbvie
# 4      2018-06-26 16:30:07+00:00            4        @abbvie
# 5      2018-06-26 12:20:06+00:00           42        @abbvie
# 6      2018-06-25 16:30:05+00:00            8        @abbvie
# 7      2018-06-25 11:20:04+00:00           27        @abbvie
# 8      2018-06-22 21:43:19+00:00           34        @abbvie
# 9      2018-06-22 17:30:11+00:00           42        @abbvie
# 10     2018-06-22 14:49:47+00:00            6        @abbvie
# 11     2018-06-22 14:22:31+00:00            0        @abbvie
# 12     2018-06-21 22:04:34+00:00            0        @abbvie
# 13     2018-06-21 18:20:14+00:00            0        @abbvie
# 14     2018-06-21 17:30:55+00:00           11        @abbvie
# 15     2018-06-21 12:00:15+00:00           28        @abbvie
# 16     2018-06-20 22:38:23+00:00            3        @abbvie
# 17     2018-06-20 22:37:53+00:00            0        @abbvie
# 18     2018-06-20 22:37:22+00:00            0        @abbvie
# 19     2018-06-20 13:30:07+00:00           17        @abbvie
# 20     2018-06-20 12:00:12+00:00           16        @abbvie
# 21     2018-06-19 22:20:42+00:00            0        @abbvie
# 22     2018-06-19 21:30:07+00:00           10        @abbvie
# 23     2018-06-19 17:01:03+00:00           13        @abbvie
# 24     2018-06-19 14:19:18+00:00           13        @abbvie
# 25     2018-06-19 14:00:15+00:00           24        @abbvie
# 26     2018-06-18 20:55:44+00:00            1        @abbvie
# 27     2018-06-18 19:51:35+00:00            0        @abbvie
# 28     2018-06-18 19:37:43+00:00           17        @abbvie
# 29     2018-06-18 17:02:16+00:00           19        @abbvie
# ...                          ...          ...            ...
# 187378 2015-11-25 14:07:05+00:00            8    @exxonmobil
# 187379 2015-11-24 23:05:08+00:00            2    @exxonmobil
# 187380 2015-11-24 20:15:07+00:00            4    @exxonmobil
# 187381 2015-11-24 17:28:47+00:00            4    @exxonmobil
# 187382 2015-11-24 15:58:07+00:00            5    @exxonmobil
# 187383 2015-11-24 15:56:55+00:00            0    @exxonmobil
# 187384 2015-11-23 23:06:08+00:00            6    @exxonmobil
# 187385 2015-11-23 20:40:04+00:00            1    @exxonmobil
# 187386 2015-11-23 18:59:58+00:00            1    @exxonmobil
# 187387 2015-11-23 17:31:07+00:00            0    @exxonmobil
# 187388 2015-11-23 14:59:11+00:00            0    @exxonmobil
# 187389 2015-11-22 23:48:03+00:00            0    @exxonmobil
# 187390 2015-11-22 22:17:03+00:00            7    @exxonmobil
# 187391 2015-11-22 20:56:05+00:00            1    @exxonmobil
# 187392 2015-11-22 18:13:03+00:00            5    @exxonmobil
# 187393 2015-11-22 15:16:04+00:00            5    @exxonmobil
# 187394 2015-11-21 23:36:06+00:00           11    @exxonmobil
# 187395 2015-11-21 21:01:05+00:00            6    @exxonmobil
# 187396 2015-11-21 18:32:06+00:00            3    @exxonmobil
# 187397 2015-11-21 16:27:05+00:00            6    @exxonmobil
# 187398 2015-11-21 14:36:06+00:00            6    @exxonmobil
# 187399 2015-11-21 00:36:04+00:00            2    @exxonmobil
# 187400 2015-11-20 23:16:04+00:00            2    @exxonmobil
# 187401 2015-11-20 22:39:06+00:00            2    @exxonmobil
# 187402 2015-11-20 21:00:07+00:00            0    @exxonmobil
# 187403 2015-11-20 20:28:42+00:00            0    @exxonmobil
# 187404 2015-11-20 20:00:17+00:00            1    @exxonmobil
# 187405 2015-11-20 18:48:07+00:00            2    @exxonmobil
# 187406 2015-11-20 18:40:04+00:00            0    @exxonmobil
# 187407 2015-11-20 17:06:06+00:00            4    @exxonmobil
#
# [187408 rows x 8 columns]

# %%
# Out:
# array([], dtype=int64)

# %%
tweet_data = pd.DataFrame({"Twitter_handle": tweet_search_keyword,
                            'Name':tweet_user,
                           'Followers':tweet_followers,
                            'Id':unique_ids,
                            'Text': tweet_text,
                           'Time Stamp':tweet_time_objects,
                            'Time Retweeted':tweet_post_retweets,
                            'Times liked':tweet_likes })

tweet_data_all = pd.merge(tweet_data,top_stocks[["Twitter_handle","industry","sector","Symbol"]], 
                on="Twitter_handle", how = "left")

# %%
# Identify incomplete rows
#df.count()
# Drop all rows with missing information
#df = df.dropna(how='any')

# %%
counter = 0

for index, row in tweet_data_all.iterrows():
    
    re_retweet = re.match(r'^(RT @)',row["Text"])
    re_url = re.findall(r'http[s]?://(?:[a-z]|[0-9]|[$-_@.&amp;+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+',row["Text"])
    re_hash = re.findall(r'(?:\#+[\w_]+[\w\'_\-]*[\w_]+)',row["Text"])
    re_at = re.findall(r'(^|[^\w@/\!?=&])@(\w{1,15})\b',row["Text"])

    if re_retweet:
        tweet_data_all.loc[index,"Retweet"] = 1
    else:
        tweet_data_all.loc[index,"Retweet"] = 0
        
    if re_url:
        tweet_data_all.lo c[index,"URL"] = 1
    else:
        tweet_data_all.loc[index,"URL"] = 0
        
    if re_hash:
        tweet_data_all.loc[index,"Hashtag"] = 1
    else:
        tweet_data_all.loc[index,"Hashtag"] = 0
        
    if re_at and not re_retweet:
        tweet_data_all.loc[index,"@ Symbol"] = 1
    else:
        tweet_data_all.loc[index,"@ Symbol"] = 0
    
    #if not re_at and not re_retweet and not re_hash and not re_url aad not re_retweet:
    #    tweet_data_all.loc[index,"Other Tweet"] = 1
    #else:
    #    tweet_data_all.loc[index,"Other Tweet"] = 0
    
    counter += 1
        
    # Print tweets for preview
    if counter % 100 == 0:
        print(f'rows processed {counter}')
# Out:
# rows processed 100
# rows processed 200
# rows processed 300
# rows processed 400
# rows processed 500
# rows processed 600
# rows processed 700
# rows processed 800
# rows processed 900
# rows processed 1000
# rows processed 1100
# rows processed 1200
# rows processed 1300
# rows processed 1400
# rows processed 1500
# rows processed 1600
# rows processed 1700
# rows processed 1800
# rows processed 1900
# rows processed 2000
# rows processed 2100
# rows processed 2200
# rows processed 2300
# rows processed 2400
# rows processed 2500
# rows processed 2600
# rows processed 2700
# rows processed 2800
# rows processed 2900
# rows processed 3000
# rows processed 3100
# rows processed 3200
# rows processed 3300
# rows processed 3400
# rows processed 3500
# rows processed 3600
# rows processed 3700
# rows processed 3800
# rows processed 3900
# rows processed 4000
# rows processed 4100
# rows processed 4200
# rows processed 4300
# rows processed 4400
# rows processed 4500
# rows processed 4600
# rows processed 4700
# rows processed 4800
# rows processed 4900
# rows processed 5000
# rows processed 5100
# rows processed 5200
# rows processed 5300
# rows processed 5400
# rows processed 5500
# rows processed 5600
# rows processed 5700
# rows processed 5800
# rows processed 5900
# rows processed 6000
# rows processed 6100
# rows processed 6200
# rows processed 6300
# rows processed 6400
# rows processed 6500
# rows processed 6600
# rows processed 6700
# rows processed 6800
# rows processed 6900
# rows processed 7000
# rows processed 7100
# rows processed 7200
# rows processed 7300
# rows processed 7400
# rows processed 7500
# rows processed 7600
# rows processed 7700
# rows processed 7800
# rows processed 7900
# rows processed 8000
# rows processed 8100
# rows processed 8200
# rows processed 8300
# rows processed 8400
# rows processed 8500
# rows processed 8600
# rows processed 8700
# rows processed 8800
# rows processed 8900
# rows processed 9000
# rows processed 9100
# rows processed 9200
# rows processed 9300
# rows processed 9400
# rows processed 9500
# rows processed 9600
# rows processed 9700
# rows processed 9800
# rows processed 9900
# rows processed 10000
# rows processed 10100
# rows processed 10200
# rows processed 10300
# rows processed 10400
# rows processed 10500
# rows processed 10600
# rows processed 10700
# rows processed 10800
# rows processed 10900
# rows processed 11000
# rows processed 11100
# rows processed 11200
# rows processed 11300
# rows processed 11400
# rows processed 11500
# rows processed 11600
# rows processed 11700
# rows processed 11800
# rows processed 11900
# rows processed 12000
# rows processed 12100
# rows processed 12200
# rows processed 12300
# rows processed 12400
# rows processed 12500
# rows processed 12600
# rows processed 12700
# rows processed 12800
# rows processed 12900
# rows processed 13000
# rows processed 13100
# rows processed 13200
# rows processed 13300
# rows processed 13400
# rows processed 13500
# rows processed 13600
# rows processed 13700
# rows processed 13800
# rows processed 13900
# rows processed 14000
# rows processed 14100
# rows processed 14200
# rows processed 14300
# rows processed 14400
# rows processed 14500
# rows processed 14600
# rows processed 14700
# rows processed 14800
# rows processed 14900
# rows processed 15000
# rows processed 15100
# rows processed 15200
# rows processed 15300
# rows processed 15400
# rows processed 15500
# rows processed 15600
# rows processed 15700
# rows processed 15800
# rows processed 15900
# rows processed 16000
# rows processed 16100
# rows processed 16200
# rows processed 16300
# rows processed 16400
# rows processed 16500
# rows processed 16600
# rows processed 16700
# rows processed 16800
# rows processed 16900
# rows processed 17000
# rows processed 17100
# rows processed 17200
# rows processed 17300
# rows processed 17400
# rows processed 17500
# rows processed 17600
# rows processed 17700
# rows processed 17800
# rows processed 17900
# rows processed 18000
# rows processed 18100
# rows processed 18200
# rows processed 18300
# rows processed 18400
# rows processed 18500
# rows processed 18600
# rows processed 18700
# rows processed 18800
# rows processed 18900
# rows processed 19000
# rows processed 19100
# rows processed 19200
# rows processed 19300
# rows processed 19400
# rows processed 19500
# rows processed 19600
# rows processed 19700
# rows processed 19800
# rows processed 19900
# rows processed 20000
# rows processed 20100
# rows processed 20200
# rows processed 20300
# rows processed 20400
# rows processed 20500
# rows processed 20600
# rows processed 20700
# rows processed 20800
# rows processed 20900
# rows processed 21000
# rows processed 21100
# rows processed 21200
# rows processed 21300
# rows processed 21400
# rows processed 21500
# rows processed 21600
# rows processed 21700
# rows processed 21800
# rows processed 21900
# rows processed 22000
# rows processed 22100
# rows processed 22200
# rows processed 22300
# rows processed 22400
# rows processed 22500
# rows processed 22600
# rows processed 22700
# rows processed 22800
# rows processed 22900
# rows processed 23000
# rows processed 23100
# rows processed 23200
# rows processed 23300
# rows processed 23400
# rows processed 23500
# rows processed 23600
# rows processed 23700
# rows processed 23800
# rows processed 23900
# rows processed 24000
# rows processed 24100
# rows processed 24200
# rows processed 24300
# rows processed 24400
# rows processed 24500
# rows processed 24600
# rows processed 24700
# rows processed 24800
# rows processed 24900
# rows processed 25000
# rows processed 25100
# rows processed 25200
# rows processed 25300
# rows processed 25400
# rows processed 25500
# rows processed 25600
# rows processed 25700
# rows processed 25800
# rows processed 25900
# rows processed 26000
# rows processed 26100
# rows processed 26200
# rows processed 26300
# rows processed 26400
# rows processed 26500
# rows processed 26600
# rows processed 26700
# rows processed 26800
# rows processed 26900
# rows processed 27000
# rows processed 27100
# rows processed 27200
# rows processed 27300
# rows processed 27400
# rows processed 27500
# rows processed 27600
# rows processed 27700
# rows processed 27800
# rows processed 27900
# rows processed 28000
# rows processed 28100
# rows processed 28200
# rows processed 28300
# rows processed 28400
# rows processed 28500
# rows processed 28600
# rows processed 28700
# rows processed 28800
# rows processed 28900
# rows processed 29000
# rows processed 29100
# rows processed 29200
# rows processed 29300
# rows processed 29400
# rows processed 29500
# rows processed 29600
# rows processed 29700
# rows processed 29800
# rows processed 29900
# rows processed 30000
# rows processed 30100
# rows processed 30200
# rows processed 30300
# rows processed 30400
# rows processed 30500
# rows processed 30600
# rows processed 30700
# rows processed 30800
# rows processed 30900
# rows processed 31000
# rows processed 31100
# rows processed 31200
# rows processed 31300
# rows processed 31400
# rows processed 31500
# rows processed 31600
# rows processed 31700
# rows processed 31800
# rows processed 31900
# rows processed 32000
# rows processed 32100
# rows processed 32200
# rows processed 32300
# rows processed 32400
# rows processed 32500
# rows processed 32600
# rows processed 32700
# rows processed 32800
# rows processed 32900
# rows processed 33000
# rows processed 33100
# rows processed 33200
# rows processed 33300
# rows processed 33400
# rows processed 33500
# rows processed 33600
# rows processed 33700
# rows processed 33800
# rows processed 33900
# rows processed 34000
# rows processed 34100
# rows processed 34200
# rows processed 34300
# rows processed 34400
# rows processed 34500
# rows processed 34600
# rows processed 34700
# rows processed 34800
# rows processed 34900
# rows processed 35000
# rows processed 35100
# rows processed 35200
# rows processed 35300
# rows processed 35400
# rows processed 35500
# rows processed 35600
# rows processed 35700
# rows processed 35800
# rows processed 35900
# rows processed 36000
# rows processed 36100
# rows processed 36200
# rows processed 36300
# rows processed 36400
# rows processed 36500
# rows processed 36600
# rows processed 36700
# rows processed 36800
# rows processed 36900
# rows processed 37000
# rows processed 37100
# rows processed 37200
# rows processed 37300
# rows processed 37400
# rows processed 37500
# rows processed 37600
# rows processed 37700
# rows processed 37800
# rows processed 37900
# rows processed 38000
# rows processed 38100
# rows processed 38200
# rows processed 38300
# rows processed 38400
# rows processed 38500
# rows processed 38600
# rows processed 38700
# rows processed 38800
# rows processed 38900
# rows processed 39000
# rows processed 39100
# rows processed 39200
# rows processed 39300
# rows processed 39400
# rows processed 39500
# rows processed 39600
# rows processed 39700
# rows processed 39800
# rows processed 39900
# rows processed 40000
# rows processed 40100
# rows processed 40200
# rows processed 40300
# rows processed 40400
# rows processed 40500
# rows processed 40600
# rows processed 40700
# rows processed 40800
# rows processed 40900
# rows processed 41000
# rows processed 41100
# rows processed 41200
# rows processed 41300
# rows processed 41400
# rows processed 41500
# rows processed 41600
# rows processed 41700
# rows processed 41800
# rows processed 41900
# rows processed 42000
# rows processed 42100
# rows processed 42200
# rows processed 42300
# rows processed 42400
# rows processed 42500
# rows processed 42600
# rows processed 42700
# rows processed 42800
# rows processed 42900
# rows processed 43000
# rows processed 43100
# rows processed 43200
# rows processed 43300
# rows processed 43400
# rows processed 43500
# rows processed 43600
# rows processed 43700
# rows processed 43800
# rows processed 43900
# rows processed 44000
# rows processed 44100
# rows processed 44200
# rows processed 44300
# rows processed 44400
# rows processed 44500
# rows processed 44600
# rows processed 44700
# rows processed 44800
# rows processed 44900
# rows processed 45000
# rows processed 45100
# rows processed 45200
# rows processed 45300
# rows processed 45400
# rows processed 45500
# rows processed 45600
# rows processed 45700
# rows processed 45800
# rows processed 45900
# rows processed 46000
# rows processed 46100
# rows processed 46200
# rows processed 46300
# rows processed 46400
# rows processed 46500
# rows processed 46600
# rows processed 46700
# rows processed 46800
# rows processed 46900
# rows processed 47000
# rows processed 47100
# rows processed 47200
# rows processed 47300
# rows processed 47400
# rows processed 47500
# rows processed 47600
# rows processed 47700
# rows processed 47800
# rows processed 47900
# rows processed 48000
# rows processed 48100
# rows processed 48200
# rows processed 48300
# rows processed 48400
# rows processed 48500
# rows processed 48600
# rows processed 48700
# rows processed 48800
# rows processed 48900
# rows processed 49000
# rows processed 49100
# rows processed 49200
# rows processed 49300
# rows processed 49400
# rows processed 49500
# rows processed 49600
# rows processed 49700
# rows processed 49800
# rows processed 49900
# rows processed 50000
# rows processed 50100
# rows processed 50200
# rows processed 50300
# rows processed 50400
# rows processed 50500
# rows processed 50600
# rows processed 50700
# rows processed 50800
# rows processed 50900
# rows processed 51000
# rows processed 51100
# rows processed 51200
# rows processed 51300
# rows processed 51400
# rows processed 51500
# rows processed 51600
# rows processed 51700
# rows processed 51800
# rows processed 51900
# rows processed 52000
# rows processed 52100
# rows processed 52200
# rows processed 52300
# rows processed 52400
# rows processed 52500
# rows processed 52600
# rows processed 52700
# rows processed 52800
# rows processed 52900
# rows processed 53000
# rows processed 53100
# rows processed 53200
# rows processed 53300
# rows processed 53400
# rows processed 53500
# rows processed 53600
# rows processed 53700
# rows processed 53800
# rows processed 53900
# rows processed 54000
# rows processed 54100
# rows processed 54200
# rows processed 54300
# rows processed 54400
# rows processed 54500
# rows processed 54600
# rows processed 54700
# rows processed 54800
# rows processed 54900
# rows processed 55000
# rows processed 55100
# rows processed 55200
# rows processed 55300
# rows processed 55400
# rows processed 55500
# rows processed 55600
# rows processed 55700
# rows processed 55800
# rows processed 55900
# rows processed 56000
# rows processed 56100
# rows processed 56200
# rows processed 56300
# rows processed 56400
# rows processed 56500
# rows processed 56600
# rows processed 56700
# rows processed 56800
# rows processed 56900
# rows processed 57000
# rows processed 57100
# rows processed 57200
# rows processed 57300
# rows processed 57400
# rows processed 57500
# rows processed 57600
# rows processed 57700
# rows processed 57800
# rows processed 57900
# rows processed 58000
# rows processed 58100
# rows processed 58200
# rows processed 58300
# rows processed 58400
# rows processed 58500
# rows processed 58600
# rows processed 58700
# rows processed 58800
# rows processed 58900
# rows processed 59000
# rows processed 59100
# rows processed 59200
# rows processed 59300
# rows processed 59400
# rows processed 59500
# rows processed 59600
# rows processed 59700
# rows processed 59800
# rows processed 59900
# rows processed 60000
# rows processed 60100
# rows processed 60200
# rows processed 60300
# rows processed 60400
# rows processed 60500
# rows processed 60600
# rows processed 60700
# rows processed 60800
# rows processed 60900
# rows processed 61000
# rows processed 61100
# rows processed 61200
# rows processed 61300
# rows processed 61400
# rows processed 61500
# rows processed 61600
# rows processed 61700
# rows processed 61800
# rows processed 61900
# rows processed 62000
# rows processed 62100
# rows processed 62200
# rows processed 62300
# rows processed 62400
# rows processed 62500
# rows processed 62600
# rows processed 62700
# rows processed 62800
# rows processed 62900
# rows processed 63000
# rows processed 63100
# rows processed 63200
# rows processed 63300
# rows processed 63400
# rows processed 63500
# rows processed 63600
# rows processed 63700
# rows processed 63800
# rows processed 63900
# rows processed 64000
# rows processed 64100
# rows processed 64200
# rows processed 64300
# rows processed 64400
# rows processed 64500
# rows processed 64600
# rows processed 64700
# rows processed 64800
# rows processed 64900
# rows processed 65000
# rows processed 65100
# rows processed 65200
# rows processed 65300
# rows processed 65400
# rows processed 65500
# rows processed 65600
# rows processed 65700
# rows processed 65800
# rows processed 65900
# rows processed 66000
# rows processed 66100
# rows processed 66200
# rows processed 66300
# rows processed 66400
# rows processed 66500
# rows processed 66600
# rows processed 66700
# rows processed 66800
# rows processed 66900
# rows processed 67000
# rows processed 67100
# rows processed 67200
# rows processed 67300
# rows processed 67400
# rows processed 67500
# rows processed 67600
# rows processed 67700
# rows processed 67800
# rows processed 67900
# rows processed 68000
# rows processed 68100
# rows processed 68200
# rows processed 68300
# rows processed 68400
# rows processed 68500
# rows processed 68600
# rows processed 68700
# rows processed 68800
# rows processed 68900
# rows processed 69000
# rows processed 69100
# rows processed 69200
# rows processed 69300
# rows processed 69400
# rows processed 69500
# rows processed 69600
# rows processed 69700
# rows processed 69800
# rows processed 69900
# rows processed 70000
# rows processed 70100
# rows processed 70200
# rows processed 70300
# rows processed 70400
# rows processed 70500
# rows processed 70600
# rows processed 70700
# rows processed 70800
# rows processed 70900
# rows processed 71000
# rows processed 71100
# rows processed 71200
# rows processed 71300
# rows processed 71400
# rows processed 71500
# rows processed 71600
# rows processed 71700
# rows processed 71800
# rows processed 71900
# rows processed 72000
# rows processed 72100
# rows processed 72200
# rows processed 72300
# rows processed 72400
# rows processed 72500
# rows processed 72600
# rows processed 72700
# rows processed 72800
# rows processed 72900
# rows processed 73000
# rows processed 73100
# rows processed 73200
# rows processed 73300
# rows processed 73400
# rows processed 73500
# rows processed 73600
# rows processed 73700
# rows processed 73800
# rows processed 73900
# rows processed 74000
# rows processed 74100
# rows processed 74200
# rows processed 74300
# rows processed 74400
# rows processed 74500
# rows processed 74600
# rows processed 74700
# rows processed 74800
# rows processed 74900
# rows processed 75000
# rows processed 75100
# rows processed 75200
# rows processed 75300
# rows processed 75400
# rows processed 75500
# rows processed 75600
# rows processed 75700
# rows processed 75800
# rows processed 75900
# rows processed 76000
# rows processed 76100
# rows processed 76200
# rows processed 76300
# rows processed 76400
# rows processed 76500
# rows processed 76600
# rows processed 76700
# rows processed 76800
# rows processed 76900
# rows processed 77000
# rows processed 77100
# rows processed 77200
# rows processed 77300
# rows processed 77400
# rows processed 77500
# rows processed 77600
# rows processed 77700
# rows processed 77800
# rows processed 77900
# rows processed 78000
# rows processed 78100
# rows processed 78200
# rows processed 78300
# rows processed 78400
# rows processed 78500
# rows processed 78600
# rows processed 78700
# rows processed 78800
# rows processed 78900
# rows processed 79000
# rows processed 79100
# rows processed 79200
# rows processed 79300
# rows processed 79400
# rows processed 79500
# rows processed 79600
# rows processed 79700
# rows processed 79800
# rows processed 79900
# rows processed 80000
# rows processed 80100
# rows processed 80200
# rows processed 80300
# rows processed 80400
# rows processed 80500
# rows processed 80600
# rows processed 80700
# rows processed 80800
# rows processed 80900
# rows processed 81000
# rows processed 81100
# rows processed 81200
# rows processed 81300
# rows processed 81400
# rows processed 81500
# rows processed 81600
# rows processed 81700
# rows processed 81800
# rows processed 81900
# rows processed 82000
# rows processed 82100
# rows processed 82200
# rows processed 82300
# rows processed 82400
# rows processed 82500
# rows processed 82600
# rows processed 82700
# rows processed 82800
# rows processed 82900
# rows processed 83000
# rows processed 83100
# rows processed 83200
# rows processed 83300
# rows processed 83400
# rows processed 83500
# rows processed 83600
# rows processed 83700
# rows processed 83800
# rows processed 83900
# rows processed 84000
# rows processed 84100
# rows processed 84200
# rows processed 84300
# rows processed 84400
# rows processed 84500
# rows processed 84600
# rows processed 84700
# rows processed 84800
# rows processed 84900
# rows processed 85000
# rows processed 85100
# rows processed 85200
# rows processed 85300
# rows processed 85400
# rows processed 85500
# rows processed 85600
# rows processed 85700
# rows processed 85800
# rows processed 85900
# rows processed 86000
# rows processed 86100
# rows processed 86200
# rows processed 86300
# rows processed 86400
# rows processed 86500
# rows processed 86600
# rows processed 86700
# rows processed 86800
# rows processed 86900
# rows processed 87000
# rows processed 87100
# rows processed 87200
# rows processed 87300
# rows processed 87400
# rows processed 87500
# rows processed 87600
# rows processed 87700
# rows processed 87800
# rows processed 87900
# rows processed 88000
# rows processed 88100
# rows processed 88200
# rows processed 88300
# rows processed 88400
# rows processed 88500
# rows processed 88600
# rows processed 88700
# rows processed 88800
# rows processed 88900
# rows processed 89000
# rows processed 89100
# rows processed 89200
# rows processed 89300
# rows processed 89400
# rows processed 89500
# rows processed 89600
# rows processed 89700
# rows processed 89800
# rows processed 89900
# rows processed 90000
# rows processed 90100
# rows processed 90200
# rows processed 90300
# rows processed 90400
# rows processed 90500
# rows processed 90600
# rows processed 90700
# rows processed 90800
# rows processed 90900
# rows processed 91000
# rows processed 91100
# rows processed 91200
# rows processed 91300
# rows processed 91400
# rows processed 91500
# rows processed 91600
# rows processed 91700
# rows processed 91800
# rows processed 91900
# rows processed 92000
# rows processed 92100
# rows processed 92200
# rows processed 92300
# rows processed 92400
# rows processed 92500
# rows processed 92600
# rows processed 92700
# rows processed 92800
# rows processed 92900
# rows processed 93000
# rows processed 93100
# rows processed 93200
# rows processed 93300
# rows processed 93400
# rows processed 93500
# rows processed 93600
# rows processed 93700
# rows processed 93800
# rows processed 93900
# rows processed 94000
# rows processed 94100
# rows processed 94200
# rows processed 94300
# rows processed 94400
# rows processed 94500
# rows processed 94600
# rows processed 94700
# rows processed 94800
# rows processed 94900
# rows processed 95000
# rows processed 95100
# rows processed 95200
# rows processed 95300
# rows processed 95400
# rows processed 95500
# rows processed 95600
# rows processed 95700
# rows processed 95800
# rows processed 95900
# rows processed 96000
# rows processed 96100
# rows processed 96200
# rows processed 96300
# rows processed 96400
# rows processed 96500
# rows processed 96600
# rows processed 96700
# rows processed 96800
# rows processed 96900
# rows processed 97000
# rows processed 97100
# rows processed 97200
# rows processed 97300
# rows processed 97400
# rows processed 97500
# rows processed 97600
# rows processed 97700
# rows processed 97800
# rows processed 97900
# rows processed 98000
# rows processed 98100
# rows processed 98200
# rows processed 98300
# rows processed 98400
# rows processed 98500
# rows processed 98600
# rows processed 98700
# rows processed 98800
# rows processed 98900
# rows processed 99000
# rows processed 99100
# rows processed 99200
# rows processed 99300
# rows processed 99400
# rows processed 99500
# rows processed 99600
# rows processed 99700
# rows processed 99800
# rows processed 99900
# rows processed 100000
# rows processed 100100
# rows processed 100200
# rows processed 100300
# rows processed 100400
# rows processed 100500
# rows processed 100600
# rows processed 100700
# rows processed 100800
# rows processed 100900
# rows processed 101000
# rows processed 101100
# rows processed 101200
# rows processed 101300
# rows processed 101400
# rows processed 101500
# rows processed 101600
# rows processed 101700
# rows processed 101800
# rows processed 101900
# rows processed 102000
# rows processed 102100
# rows processed 102200
# rows processed 102300
# rows processed 102400
# rows processed 102500
# rows processed 102600
# rows processed 102700
# rows processed 102800
# rows processed 102900
# rows processed 103000
# rows processed 103100
# rows processed 103200
# rows processed 103300
# rows processed 103400
# rows processed 103500
# rows processed 103600
# rows processed 103700
# rows processed 103800
# rows processed 103900
# rows processed 104000
# rows processed 104100
# rows processed 104200
# rows processed 104300
# rows processed 104400
# rows processed 104500
# rows processed 104600
# rows processed 104700
# rows processed 104800
# rows processed 104900
# rows processed 105000
# rows processed 105100
# rows processed 105200
# rows processed 105300
# rows processed 105400
# rows processed 105500
# rows processed 105600
# rows processed 105700
# rows processed 105800
# rows processed 105900
# rows processed 106000
# rows processed 106100
# rows processed 106200
# rows processed 106300
# rows processed 106400
# rows processed 106500
# rows processed 106600
# rows processed 106700
# rows processed 106800
# rows processed 106900
# rows processed 107000
# rows processed 107100
# rows processed 107200
# rows processed 107300
# rows processed 107400
# rows processed 107500
# rows processed 107600
# rows processed 107700
# rows processed 107800
# rows processed 107900
# rows processed 108000
# rows processed 108100
# rows processed 108200
# rows processed 108300
# rows processed 108400
# rows processed 108500
# rows processed 108600
# rows processed 108700
# rows processed 108800
# rows processed 108900
# rows processed 109000
# rows processed 109100
# rows processed 109200
# rows processed 109300
# rows processed 109400
# rows processed 109500
# rows processed 109600
# rows processed 109700
# rows processed 109800
# rows processed 109900
# rows processed 110000
# rows processed 110100
# rows processed 110200
# rows processed 110300
# rows processed 110400
# rows processed 110500
# rows processed 110600
# rows processed 110700
# rows processed 110800
# rows processed 110900
# rows processed 111000
# rows processed 111100
# rows processed 111200
# rows processed 111300
# rows processed 111400
# rows processed 111500
# rows processed 111600
# rows processed 111700
# rows processed 111800
# rows processed 111900
# rows processed 112000
# rows processed 112100
# rows processed 112200
# rows processed 112300
# rows processed 112400
# rows processed 112500
# rows processed 112600
# rows processed 112700
# rows processed 112800
# rows processed 112900
# rows processed 113000
# rows processed 113100
# rows processed 113200
# rows processed 113300
# rows processed 113400
# rows processed 113500
# rows processed 113600
# rows processed 113700
# rows processed 113800
# rows processed 113900
# rows processed 114000
# rows processed 114100
# rows processed 114200
# rows processed 114300
# rows processed 114400
# rows processed 114500
# rows processed 114600
# rows processed 114700
# rows processed 114800
# rows processed 114900
# rows processed 115000
# rows processed 115100
# rows processed 115200
# rows processed 115300
# rows processed 115400
# rows processed 115500
# rows processed 115600
# rows processed 115700
# rows processed 115800
# rows processed 115900
# rows processed 116000
# rows processed 116100
# rows processed 116200
# rows processed 116300
# rows processed 116400
# rows processed 116500
# rows processed 116600
# rows processed 116700
# rows processed 116800
# rows processed 116900
# rows processed 117000
# rows processed 117100
# rows processed 117200
# rows processed 117300
# rows processed 117400
# rows processed 117500
# rows processed 117600
# rows processed 117700
# rows processed 117800
# rows processed 117900
# rows processed 118000
# rows processed 118100
# rows processed 118200
# rows processed 118300
# rows processed 118400
# rows processed 118500
# rows processed 118600
# rows processed 118700
# rows processed 118800
# rows processed 118900
# rows processed 119000
# rows processed 119100
# rows processed 119200
# rows processed 119300
# rows processed 119400
# rows processed 119500
# rows processed 119600
# rows processed 119700
# rows processed 119800
# rows processed 119900
# rows processed 120000
# rows processed 120100
# rows processed 120200
# rows processed 120300
# rows processed 120400
# rows processed 120500
# rows processed 120600
# rows processed 120700
# rows processed 120800
# rows processed 120900
# rows processed 121000
# rows processed 121100
# rows processed 121200
# rows processed 121300
# rows processed 121400
# rows processed 121500
# rows processed 121600
# rows processed 121700
# rows processed 121800
# rows processed 121900
# rows processed 122000
# rows processed 122100
# rows processed 122200
# rows processed 122300
# rows processed 122400
# rows processed 122500
# rows processed 122600
# rows processed 122700
# rows processed 122800
# rows processed 122900
# rows processed 123000
# rows processed 123100
# rows processed 123200
# rows processed 123300
# rows processed 123400
# rows processed 123500
# rows processed 123600
# rows processed 123700
# rows processed 123800
# rows processed 123900
# rows processed 124000
# rows processed 124100
# rows processed 124200
# rows processed 124300
# rows processed 124400
# rows processed 124500
# rows processed 124600
# rows processed 124700
# rows processed 124800
# rows processed 124900
# rows processed 125000
# rows processed 125100
# rows processed 125200
# rows processed 125300
# rows processed 125400
# rows processed 125500
# rows processed 125600
# rows processed 125700
# rows processed 125800
# rows processed 125900
# rows processed 126000
# rows processed 126100
# rows processed 126200
# rows processed 126300
# rows processed 126400
# rows processed 126500
# rows processed 126600
# rows processed 126700
# rows processed 126800
# rows processed 126900
# rows processed 127000
# rows processed 127100
# rows processed 127200
# rows processed 127300
# rows processed 127400
# rows processed 127500
# rows processed 127600
# rows processed 127700
# rows processed 127800
# rows processed 127900
# rows processed 128000
# rows processed 128100
# rows processed 128200
# rows processed 128300
# rows processed 128400
# rows processed 128500
# rows processed 128600
# rows processed 128700
# rows processed 128800
# rows processed 128900
# rows processed 129000
# rows processed 129100
# rows processed 129200
# rows processed 129300
# rows processed 129400
# rows processed 129500
# rows processed 129600
# rows processed 129700
# rows processed 129800
# rows processed 129900
# rows processed 130000
# rows processed 130100
# rows processed 130200
# rows processed 130300
# rows processed 130400
# rows processed 130500
# rows processed 130600
# rows processed 130700
# rows processed 130800
# rows processed 130900
# rows processed 131000
# rows processed 131100
# rows processed 131200
# rows processed 131300
# rows processed 131400
# rows processed 131500
# rows processed 131600
# rows processed 131700
# rows processed 131800
# rows processed 131900
# rows processed 132000
# rows processed 132100
# rows processed 132200
# rows processed 132300
# rows processed 132400
# rows processed 132500
# rows processed 132600
# rows processed 132700
# rows processed 132800
# rows processed 132900
# rows processed 133000
# rows processed 133100
# rows processed 133200
# rows processed 133300
# rows processed 133400
# rows processed 133500
# rows processed 133600
# rows processed 133700
# rows processed 133800
# rows processed 133900
# rows processed 134000
# rows processed 134100
# rows processed 134200
# rows processed 134300
# rows processed 134400
# rows processed 134500
# rows processed 134600
# rows processed 134700
# rows processed 134800
# rows processed 134900
# rows processed 135000
# rows processed 135100
# rows processed 135200
# rows processed 135300
# rows processed 135400
# rows processed 135500
# rows processed 135600
# rows processed 135700
# rows processed 135800
# rows processed 135900
# rows processed 136000
# rows processed 136100
# rows processed 136200
# rows processed 136300
# rows processed 136400
# rows processed 136500
# rows processed 136600
# rows processed 136700
# rows processed 136800
# rows processed 136900
# rows processed 137000
# rows processed 137100
# rows processed 137200
# rows processed 137300
# rows processed 137400
# rows processed 137500
# rows processed 137600
# rows processed 137700
# rows processed 137800
# rows processed 137900
# rows processed 138000
# rows processed 138100
# rows processed 138200
# rows processed 138300
# rows processed 138400
# rows processed 138500
# rows processed 138600
# rows processed 138700
# rows processed 138800
# rows processed 138900
# rows processed 139000
# rows processed 139100
# rows processed 139200
# rows processed 139300
# rows processed 139400
# rows processed 139500
# rows processed 139600
# rows processed 139700
# rows processed 139800
# rows processed 139900
# rows processed 140000
# rows processed 140100
# rows processed 140200
# rows processed 140300
# rows processed 140400
# rows processed 140500
# rows processed 140600
# rows processed 140700
# rows processed 140800
# rows processed 140900
# rows processed 141000
# rows processed 141100
# rows processed 141200
# rows processed 141300
# rows processed 141400
# rows processed 141500
# rows processed 141600
# rows processed 141700
# rows processed 141800
# rows processed 141900
# rows processed 142000
# rows processed 142100
# rows processed 142200
# rows processed 142300
# rows processed 142400
# rows processed 142500
# rows processed 142600
# rows processed 142700
# rows processed 142800
# rows processed 142900
# rows processed 143000
# rows processed 143100
# rows processed 143200
# rows processed 143300
# rows processed 143400
# rows processed 143500
# rows processed 143600
# rows processed 143700
# rows processed 143800
# rows processed 143900
# rows processed 144000
# rows processed 144100
# rows processed 144200
# rows processed 144300
# rows processed 144400
# rows processed 144500
# rows processed 144600
# rows processed 144700
# rows processed 144800
# rows processed 144900
# rows processed 145000
# rows processed 145100
# rows processed 145200
# rows processed 145300
# rows processed 145400
# rows processed 145500
# rows processed 145600
# rows processed 145700
# rows processed 145800
# rows processed 145900
# rows processed 146000
# rows processed 146100
# rows processed 146200
# rows processed 146300
# rows processed 146400
# rows processed 146500
# rows processed 146600
# rows processed 146700
# rows processed 146800
# rows processed 146900
# rows processed 147000
# rows processed 147100
# rows processed 147200
# rows processed 147300
# rows processed 147400
# rows processed 147500
# rows processed 147600
# rows processed 147700
# rows processed 147800
# rows processed 147900
# rows processed 148000
# rows processed 148100
# rows processed 148200
# rows processed 148300
# rows processed 148400
# rows processed 148500
# rows processed 148600
# rows processed 148700
# rows processed 148800
# rows processed 148900
# rows processed 149000
# rows processed 149100
# rows processed 149200
# rows processed 149300
# rows processed 149400
# rows processed 149500
# rows processed 149600
# rows processed 149700
# rows processed 149800
# rows processed 149900
# rows processed 150000
# rows processed 150100
# rows processed 150200
# rows processed 150300
# rows processed 150400
# rows processed 150500
# rows processed 150600
# rows processed 150700
# rows processed 150800
# rows processed 150900
# rows processed 151000
# rows processed 151100
# rows processed 151200
# rows processed 151300
# rows processed 151400
# rows processed 151500
# rows processed 151600
# rows processed 151700
# rows processed 151800
# rows processed 151900
# rows processed 152000
# rows processed 152100
# rows processed 152200
# rows processed 152300
# rows processed 152400
# rows processed 152500
# rows processed 152600
# rows processed 152700
# rows processed 152800
# rows processed 152900
# rows processed 153000
# rows processed 153100
# rows processed 153200
# rows processed 153300
# rows processed 153400
# rows processed 153500
# rows processed 153600
# rows processed 153700
# rows processed 153800
# rows processed 153900
# rows processed 154000
# rows processed 154100
# rows processed 154200
# rows processed 154300
# rows processed 154400
# rows processed 154500
# rows processed 154600
# rows processed 154700
# rows processed 154800
# rows processed 154900
# rows processed 155000
# rows processed 155100
# rows processed 155200
# rows processed 155300
# rows processed 155400
# rows processed 155500
# rows processed 155600
# rows processed 155700
# rows processed 155800
# rows processed 155900
# rows processed 156000
# rows processed 156100
# rows processed 156200
# rows processed 156300
# rows processed 156400
# rows processed 156500
# rows processed 156600
# rows processed 156700
# rows processed 156800
# rows processed 156900
# rows processed 157000
# rows processed 157100
# rows processed 157200
# rows processed 157300
# rows processed 157400
# rows processed 157500
# rows processed 157600
# rows processed 157700
# rows processed 157800
# rows processed 157900
# rows processed 158000
# rows processed 158100
# rows processed 158200
# rows processed 158300
# rows processed 158400
# rows processed 158500
# rows processed 158600
# rows processed 158700
# rows processed 158800
# rows processed 158900
# rows processed 159000
# rows processed 159100
# rows processed 159200
# rows processed 159300
# rows processed 159400
# rows processed 159500
# rows processed 159600
# rows processed 159700
# rows processed 159800
# rows processed 159900
# rows processed 160000
# rows processed 160100
# rows processed 160200
# rows processed 160300
# rows processed 160400
# rows processed 160500
# rows processed 160600
# rows processed 160700
# rows processed 160800
# rows processed 160900
# rows processed 161000
# rows processed 161100
# rows processed 161200
# rows processed 161300
# rows processed 161400
# rows processed 161500
# rows processed 161600
# rows processed 161700
# rows processed 161800
# rows processed 161900
# rows processed 162000
# rows processed 162100
# rows processed 162200
# rows processed 162300
# rows processed 162400
# rows processed 162500
# rows processed 162600
# rows processed 162700
# rows processed 162800
# rows processed 162900
# rows processed 163000
# rows processed 163100
# rows processed 163200
# rows processed 163300
# rows processed 163400
# rows processed 163500
# rows processed 163600
# rows processed 163700
# rows processed 163800
# rows processed 163900
# rows processed 164000
# rows processed 164100
# rows processed 164200
# rows processed 164300
# rows processed 164400
# rows processed 164500
# rows processed 164600
# rows processed 164700
# rows processed 164800
# rows processed 164900
# rows processed 165000
# rows processed 165100
# rows processed 165200
# rows processed 165300
# rows processed 165400
# rows processed 165500
# rows processed 165600
# rows processed 165700
# rows processed 165800
# rows processed 165900
# rows processed 166000
# rows processed 166100
# rows processed 166200
# rows processed 166300
# rows processed 166400
# rows processed 166500
# rows processed 166600
# rows processed 166700
# rows processed 166800
# rows processed 166900
# rows processed 167000
# rows processed 167100
# rows processed 167200
# rows processed 167300
# rows processed 167400
# rows processed 167500
# rows processed 167600
# rows processed 167700
# rows processed 167800
# rows processed 167900
# rows processed 168000
# rows processed 168100
# rows processed 168200
# rows processed 168300
# rows processed 168400
# rows processed 168500
# rows processed 168600
# rows processed 168700
# rows processed 168800
# rows processed 168900
# rows processed 169000
# rows processed 169100
# rows processed 169200
# rows processed 169300
# rows processed 169400
# rows processed 169500
# rows processed 169600
# rows processed 169700
# rows processed 169800
# rows processed 169900
# rows processed 170000
# rows processed 170100
# rows processed 170200
# rows processed 170300
# rows processed 170400
# rows processed 170500
# rows processed 170600
# rows processed 170700
# rows processed 170800
# rows processed 170900
# rows processed 171000
# rows processed 171100
# rows processed 171200
# rows processed 171300
# rows processed 171400
# rows processed 171500
# rows processed 171600
# rows processed 171700
# rows processed 171800
# rows processed 171900
# rows processed 172000
# rows processed 172100
# rows processed 172200
# rows processed 172300
# rows processed 172400
# rows processed 172500
# rows processed 172600
# rows processed 172700
# rows processed 172800
# rows processed 172900
# rows processed 173000
# rows processed 173100
# rows processed 173200
# rows processed 173300
# rows processed 173400
# rows processed 173500
# rows processed 173600
# rows processed 173700
# rows processed 173800
# rows processed 173900
# rows processed 174000
# rows processed 174100
# rows processed 174200
# rows processed 174300
# rows processed 174400
# rows processed 174500
# rows processed 174600
# rows processed 174700
# rows processed 174800
# rows processed 174900
# rows processed 175000
# rows processed 175100
# rows processed 175200
# rows processed 175300
# rows processed 175400
# rows processed 175500
# rows processed 175600
# rows processed 175700
# rows processed 175800
# rows processed 175900
# rows processed 176000
# rows processed 176100
# rows processed 176200
# rows processed 176300
# rows processed 176400
# rows processed 176500
# rows processed 176600
# rows processed 176700
# rows processed 176800
# rows processed 176900
# rows processed 177000
# rows processed 177100
# rows processed 177200
# rows processed 177300
# rows processed 177400
# rows processed 177500
# rows processed 177600
# rows processed 177700
# rows processed 177800
# rows processed 177900
# rows processed 178000
# rows processed 178100
# rows processed 178200
# rows processed 178300
# rows processed 178400
# rows processed 178500
# rows processed 178600
# rows processed 178700
# rows processed 178800
# rows processed 178900
# rows processed 179000
# rows processed 179100
# rows processed 179200
# rows processed 179300
# rows processed 179400
# rows processed 179500
# rows processed 179600
# rows processed 179700
# rows processed 179800
# rows processed 179900
# rows processed 180000
# rows processed 180100
# rows processed 180200
# rows processed 180300
# rows processed 180400
# rows processed 180500
# rows processed 180600
# rows processed 180700
# rows processed 180800
# rows processed 180900
# rows processed 181000
# rows processed 181100
# rows processed 181200
# rows processed 181300
# rows processed 181400
# rows processed 181500
# rows processed 181600
# rows processed 181700
# rows processed 181800
# rows processed 181900
# rows processed 182000
# rows processed 182100
# rows processed 182200
# rows processed 182300
# rows processed 182400
# rows processed 182500
# rows processed 182600
# rows processed 182700
# rows processed 182800
# rows processed 182900
# rows processed 183000
# rows processed 183100
# rows processed 183200
# rows processed 183300
# rows processed 183400
# rows processed 183500
# rows processed 183600
# rows processed 183700
# rows processed 183800
# rows processed 183900
# rows processed 184000
# rows processed 184100
# rows processed 184200
# rows processed 184300
# rows processed 184400
# rows processed 184500
# rows processed 184600
# rows processed 184700
# rows processed 184800
# rows processed 184900
# rows processed 185000
# rows processed 185100
# rows processed 185200
# rows processed 185300
# rows processed 185400
# rows processed 185500
# rows processed 185600
# rows processed 185700
# rows processed 185800
# rows processed 185900
# rows processed 186000
# rows processed 186100
# rows processed 186200
# rows processed 186300
# rows processed 186400
# rows processed 186500
# rows processed 186600
# rows processed 186700
# rows processed 186800
# rows processed 186900
# rows processed 187000
# rows processed 187100
# rows processed 187200
# rows processed 187300
# rows processed 187400

# %%
tweet_data_all = tweet_data_all.dropna(how='any')

# %%
tweet_data_all.to_csv("tweet_data_all.csv")
# Out:
#    Followers                   Id    Name  \
# 0      49773  1012722879467835394  AbbVie
# 1      49773  1012312191851167744  AbbVie
# 2      49773  1011949798172299264  AbbVie
# 3      49773  1011696513259655169  AbbVie
# 4      49773  1011647806719881217  AbbVie
#
#                                                 Text  Time Retweeted  \
# 0  We know more today about the biology and genet...               1
# 1  “You probably don’t think about it, but there’...               8
# 2  If you had a higher chance of developing #Alzh...               1
# 3  Learn more about the progress of our Calico pa...               7
# 4  We know patients have lots of questions before...               3
#
#                  Time Stamp  Times liked Twitter_handle            industry  \
# 0 2018-06-29 15:42:04+00:00            3        @abbvie  Drug Manufacturers
# 1 2018-06-28 12:30:09+00:00           23        @abbvie  Drug Manufacturers
# 2 2018-06-27 12:30:07+00:00           13        @abbvie  Drug Manufacturers
# 3 2018-06-26 19:43:39+00:00           14        @abbvie  Drug Manufacturers
# 4 2018-06-26 16:30:07+00:00            4        @abbvie  Drug Manufacturers
#
#        sector Symbol  Retweet  URL  Hashtag  @ Symbol
# 0  Healthcare   ABBV      0.0  1.0      1.0       0.0
# 1  Healthcare   ABBV      0.0  1.0      0.0       0.0
# 2  Healthcare   ABBV      0.0  1.0      1.0       0.0
# 3  Healthcare   ABBV      0.0  1.0      0.0       1.0
# 4  Healthcare   ABBV      0.0  1.0      1.0       0.0

# %%
industry_group = tweet_data_all.groupby("industry")

industry_summary = pd.DataFrame(industry_group["Text"].count())
industry_summary = industry_summary.rename(columns={"Text" : "Tweet Count"})

industry_summary.sort_values(by="Tweet Count", ascending= False)
industry_summary = industry_summary.reset_index()

industry_summary.head(5)
# Out:
#                industry  Tweet Count
# 0   Aerospace & Defense        10990
# 1  Application Software         8796
# 2      Asset Management         4400
# 3                 Autos         4400
# 4                 Banks         8791

# %%
company_industry_stats = tweet_data_all[["Name","industry"]]
company_industry_stats = company_data.drop_duplicates(['industry','Name'])

company_industry_df = company_industry_stats.groupby("industry",as_index=False).count()
company_industry_df = company_industry_df.rename(columns = {"Name" : "Num of Companies"})

company_industry_df["Percent of Total"] = (company_industry_df['Num of Companies'] / company_industry_df["industry"].count() ) 

industry_final = pd.merge(industry_summary,company_industry_df[["industry","Num of Companies","Percent of Total"]], on="industry" , how = "left")

industry_final["Percent of Total"] = industry_final["Percent of Total"].map('{:,.2%}'.format)

industry_final.head(5)
# Out:
#                industry  Tweet Count  Num of Companies Percent of Total
# 0   Aerospace & Defense        10990                 5           13.89%
# 1  Application Software         8796                 4           11.11%
# 2      Asset Management         4400                 2            5.56%
# 3                 Autos         4400                 2            5.56%
# 4                 Banks         8791                 4           11.11%

# %%
sector_list = industry_final["industry"].tolist()
count_list =  industry_final["Tweet Count"].tolist()
percent_list = industry_final["Percent of Total"].tolist()

data = [go.Bar(x=sector_list,y=count_list, text = percent_list, textposition = 'auto',
            marker=dict(color='rgb(58,200,225)',line=dict(color='rgb(8,48,107)',width=1.5),),opacity=0.6)]

layout = go.Layout(title='Industry Breakdown of Tweets',xaxis=dict(tickangle=-65),
                   yaxis=dict(title="Tweets",showgrid=False),margin=go.Margin(b=200))

fig = go.Figure(data=data, layout=layout)

py.iplot(fig, filename='basic-bar')
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~joelboyette/0 or inside your plot.ly account where it is named 'basic-bar'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~joelboyette/0.embed" height="525px" width="100%"></iframe>

# %%
company_group = tweet_data_all.groupby("Name")
company_summary = pd.DataFrame(company_group["Text"].count())
company_summary["Retweet"] = company_group["Retweet"].sum()
company_summary["URL"] = company_group["URL"].sum()
company_summary["Hashtag"] = company_group["Hashtag"].sum()
company_summary["@ Symbol"] = company_group["@ Symbol"].sum()

company_summary = company_summary.rename(columns={"Text" : "Tweet Count"})
company_summary = company_summary.reset_index()
company_summary.head()
# Out:
#                Name  Tweet Count  Retweet     URL  Hashtag  @ Symbol
# 0  20th Century Fox         2195   1519.0  1646.0   1575.0     398.0
# 1                3M         2200    110.0   983.0    459.0    1767.0
# 2               AIG         2200    185.0  1363.0    367.0    1007.0
# 3              AT&T         2200      9.0  1616.0    139.0    2159.0
# 4            AbbVie         2200    129.0  2029.0   1446.0     537.0

# %%
name_list = company_summary["Name"].tolist()
retweet_list = company_summary["Retweet"].tolist()
url_list = company_summary["URL"].tolist()
hashtag_list = company_summary["Hashtag"].tolist()
symbol_list = company_summary["@ Symbol"].tolist()

trace1 = go.Bar(x=name_list, y=retweet_list, name="retweet",marker=dict(color = 'rgb(58,200,225)'))
trace2 = go.Bar(x=name_list, y=url_list, name='url',marker=dict(color = 'rgb(113, 165, 214)'))
trace3 = go.Bar(x=name_list, y=symbol_list, name='@ Symbol',marker=dict(color = 'rgb(113, 214, 140)'))
trace4 = go.Bar(x=name_list, y=hashtag_list, name='Hashtag',marker=dict(color = 'rgb(214, 113, 143)'))

data = [trace1, trace2, trace3, trace4] 
layout = go.Layout( title='Types of Tweets by Company', xaxis=dict(tickangle=-85,dtick = 1.5), 
                   yaxis=dict(title="Type of Tweet",showgrid=False) , barmode='stack', margin=go.Margin(b=160))

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='stacked-bar')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~joelboyette/2.embed" height="525px" width="100%"></iframe>
